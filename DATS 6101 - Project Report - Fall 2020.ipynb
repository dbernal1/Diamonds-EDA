# %% [markdown]
# <font size="3"><center>**Diamond Prices: Exploratory Data Analysis and Visualization**<center><font>
#
# <font size="3"><center>**Characteristics that Influence the Price of a Diamond**<center><font>

# %% [markdown]
# <img src="https://media3.giphy.com/media/46rXT61bNDxAc/giphy.gif?cid=ecf05e478b58dea2be88bd4819efad80c58aca06f8ee38d5&rid=giphy.gif" width="800" height="800"/>

# %% [markdown]
# **Authors:
# Zheyue Wang, Daniel Bernal, and Meron Metaferia**

# %% [markdown]
# # 1) Introduction

# %% [markdown]
# Diamond is a solid form of the element carbon with its atoms are arranged in a crystal structure called diamond cubic. This carbon has been one of the most sough-after and expensive gemstones for various industiral and decorative purposes since the ancient time. The hardness, brilliance, and sparkle of diamonds make them unsurpassed as gems.
#
# The value of a diamond is determined by what are commonly known as the Four "C's" of a Diamond. These C's stand for carat weight, clarity, color, and the quality of its cut. Most diamonds' color ranges from clear to yellow to brown with the clear being the most expensive. Cut refers to how a diamond’s facets interact with light. It is determined by symmetry, proportion and polish. Carat denotes the weight of a diamond, not the size. Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification. A stone is graded as flawless if, under 10-power magnification, no inclusions (internal flaws) and no blemishes (external imperfections) are visible.
#
# In this project, we will be implementing an exploratory approach to analyze our data and suggest which C of a diamond is the most determinant factor for its value.

# %% [markdown]
# <img src=https://customjewelry.co.za/wp-content/uploads/2019/02/4Cs.jpg width="500">
#
#
#
#
# <center>Figure 1: The Four "C's" that Determine Diamond Quality</center>

# %% [markdown]
# # 2) At a glance of the Dataset

# %% [markdown]
# **2.1) What is known about the dataset?**

# %% [markdown]
# The diamonds [dataset](https://www.kaggle.com/shivam2503/diamonds) for this project comes from Kaggle. The dataset contains the prices of 53,940 diamonds and 10 different characteristics including the price for each piece. The 10 columns include:
# * Price in USD (326-18,823)
# * Carat weight of the diamond (0.2 -5.01)
# * Cut quality (Fair, Good, Very Good, Premium, Ideal)
# * Clarity a measurement of how clear the diamond is (l1 (worst), S12, S11, VS2, VS1, VVS2, VVS1, IF (best))
# * Depth total depth percentage = z/mean(x,y) = 2 * z/(x+y)(43-79)
# * Table width of top of diamond relative to widest point (43-95)
# * x length in mm (0-10.74)
# * y width in mm (0-58.9)
# * z depth in mm (0-31.8)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# <center>Figure 2: Diamond Measurement Illustration </center>

# %% [markdown]
# The raw data collection methdology /strategy is unknown as it was downloaded from a kaggle. Hence, the accuracy of the data is compromised, which will be the main limitation to the data.

# %% [markdown]
# **2.2 What additional information would be beneficial?**

# %% [markdown]
# In the dataset, prices are listed as U.S dollars. However, it is not clearly known when the data was collected. Hence, which year the dollar value prices correspond to is not known. Additionally, we would've prefered to know if the data belongs to a specific store, market, etc. Lastly, and most importantly, the source from the data is completely unknown.

# %% [markdown]
# # 3) Development of a Research Driven (SMART) Question

# %% [markdown]
# To develop a reasearch driven SMART question. We broke down the SMART into each of it's components and followed standardized questions to come up with our answers and have a clear vision of what our analysis should achieve.

# %% [markdown]
# **3.1 Specific**

# %% [markdown]
# a) What will you achieve?

# %% [markdown]
# This analysis will determine which feature influences price of a diamond more. After, the feature has been dissected, further analysis will be done on that attribute.

# %% [markdown]
# b) How will you know when it is done?

# %% [markdown]
# This analysis is considered as done, when we have establilished a pattern between some features of a diamond and it's prices. Furthermore, when our analysis is clearly organized and when meaningful information can be extrapolated from our report.

# %% [markdown]
# **3.2 Measurable**

# %% [markdown]
# a) If applicable, what are the quantity expectations?

# %% [markdown]
# Preliminarily, we have decided to do anova test, regression, z-test.

# %% [markdown]
# b) If applicable, what are the quality expecations?

# %% [markdown]
# The main quality expecations are error free, clearly organized, and statistical meaningful results.

# %% [markdown]
# c) What are cost expectations?

# %% [markdown]
# Zero.

# %% [markdown]
# **3.3 Achievable**

# %% [markdown]
# a) What are the knowledge, skills, ablities, and experience needed the achieve the objective?

# %% [markdown]
# * Statisistical Knowledge.
# * Python Programming.

# %% [markdown]
# b) Are there aviablable resources to achieve the objective? If so, what are they?

# %% [markdown]
# * Groupwork, dataset, time, internet connection, resources provided from our professor, books recommended for the course, Jupyter Notebook.

# %% [markdown]
# c) Are there any time factors or environmental constraints that need to be considered?

# %% [markdown]
# * Group availability, Face-to-face meeting are not possible.

# %% [markdown]
# **3.4 Relevant**

# %% [markdown]
# a) Why is this analysis necessary and what will be the impact?

# %% [markdown]
# * Different data collection strategies may affect the outcome of the analysis. Data could be gathered from different regions of the world and this may have an impact on the price.
# * Will allow the audince to compare and determine the best diamond options based on thier needs of diamond features.
# * For aspiring businessman looking to open diamond shops. This analysis will be a good way to study about the diamonds features and their prices.
# * Help the people that are currently in the diamond market. It will enable them to study the features of a diamond and decide which diamonds are best to restock based on company's yearly budget and demand.

# %% [markdown]
# **3.5 Time-Oriented**

# %% [markdown]
# a) When does it need to be completed?
# * December 1st - all the reports, slides, jupyter notebook to be submitted.
# * December 2nd - group presentation will be held.

# %% [markdown]
# # 4) Exploratory Data Analysis

# %% [markdown]
# **4.1 Data Manipulation**

# %% [markdown]
# Columns x, y, and z  were renamed as depth, width, and length respectively, for clarification purposes. In addition, for ease of analysis, we grouped the dataframes by cut type.

# %% [markdown]
# `![image.png](attachment:image.png)
#
# <center>Figure 3: Visual summary of the grouped by and column renamed dataset  </center>

# %% [markdown]
# **4.2 Summary of the Data**

# %% [markdown]
# The dataframes that we will be using have the following shapes:
#
# - df: (53940,10)
# - fair: (1610, 10)
# - good: (4906, 10)
# - ideal: (21551, 10)
# - premium: (13791, 10)
# - very_good: (12082, 10)
#
# We will be treating dataframes that contain 7 quantitative variables and 3 categorical variables. The categorical variables include:
#
# - color: ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# - cut: ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# - clarity: ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %% [markdown]
# **4.2.1 Descriptive Statistics of the Entire Dataset**

# %% [markdown]
# Continuing with the summary of the dataset, descriptive statistics provides us the opportunity to have a simpler interpreation of the data by summarizing all the quantitative variables.
#
# We find that:
#
# - Prinice range goes from \\$326 to \\$18,823.
# - Mean price is \\$3,932.
# - Carat range goes from .20 to 5.01.
# - Mean carat is .79.
# - Maximum table value 95 mm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4.3 Graphical Representation of the Data**

# %% [markdown]
# **4.3.1 Price Distribution for the Entire Dataset**

# %% [markdown]
# - In the figure below we can see that around 5700 diamonds in this dataset fall in the price range of \\$600 - \\$800.
# - Mode of price is significantly less than the average price.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **4.3.2 Price per Carat**

# %% [markdown]
# - For the majority of the diamonds the price per carat ranges between \\$2,000 and \\$4,000
# - It is commonly known that carat has a a direct impact with price. However in some ocassions carat may not be the determinant as some people have other preferences, therefore, we will further analyze other characteristics of a diamond.

# %% [markdown]
# ![newplot%20%2814%29.png](attachment:newplot%20%2814%29.png)

# %% [markdown]
# **4.3.3 Analyzing Color Quality**

# %% [markdown]
# We have a total of 7 categories in color quality. They all go in alphabetical order and E represents the highest quality.
# Eventhough the best quality color for a diamond is E, we can see that color G diamonds are the most frequent type and represent the biggest share of the pie in prices. Total count for this individual attribute is over 10,000.
#
# - Color Quality:
#
#    - D : Best Quality
#    - E
#    - F
#    - G
#    - H
#    - I
#    - J : Worst Quality

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Average Price Comparison based on Color Quality**

# %% [markdown]
# ![newplot%20%2815%29.png](attachment:newplot%20%2815%29.png)

# %% [markdown]
# For diamond **D** - the highest quality diamonds, minimum price falls at \\$357 dollars with a maximum as high as \\$18,700 dollars. For the worst quality **J**, we have minimum value of \\$335 with an upper range of \\$16,400, and some outliers that go as high as \\$18,700.

# %% [markdown]
# **4.3.4 Analyzing Clarity Rating**

# %% [markdown]
# In this dataset we have 8 different ratings:
#
#    - IF : Highest Clarity Rating
#    - VVS1
#    - VVS2
#    - VS1
#    - VS2
#    - SI1
#    - SI2
#    - I1: Lowest Clarity Rating
#
# In terms of volume SI1 represents the highest amount, which means that the clarity ratings of these diamonds may not be the best one. Similarly, SI1 aggregated prices correspond to almost a quarter compared to the rest of the diamonds.

# %% [markdown]
# ![newplot%20%2816%29.png](attachment:newplot%20%2816%29.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Price Comparison based on Clarity Rating**

# %% [markdown]
# ![newplot%20%2817%29.png](attachment:newplot%20%2817%29.png)

# %% [markdown]
# From this box plot, the highest quality diamonds **IF** has min values of \\$369 with the maximimum price going up to \\$18,800. Followed by **SI1** with the minimum price of \\$326 and maximum of \\$18,800

# %% [markdown]
# **4.3.5 Analyzing Cut Types**

# %% [markdown]
# After grouping by cut types we can observe that fair cut type has the least number of values, whereas the ideal cut type has the most vaules. Premium cuts represent the second group in volume, but its aggregated price value is close to the fair cut despite having significantly lower volume levels.
#
# One of the most eye-catching results here is the volume levels. A probable reason could be the lower number of categories. However, we identify a tendency for Ideal diamonds. From previous categories we consider that there was not such a big gap in between them, therefore, it raises doubts about the relevance of cuts and if it is a cause of diamond preference.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![newplot%20%2819%29.png](attachment:newplot%20%2819%29.png)

# %% [markdown]
# **Price Comparison based on Cut Type**

# %% [markdown]
# ![newplot%20%2818%29.png](attachment:newplot%20%2818%29.png)

# %% [markdown]
# In the boxplot, we can see that **Premium** cut types are the most expensive ones with an upper fence of \\$14,171 and outliers going up to a maximum of \\$18,823. Followed by the **Ideal** cuts which have a maximum of \\$18,806

# %% [markdown]
# **4.4 EDA Findings**

# %% [markdown]
# Following these illustrations we can say that there is a preference for:
# - Diamonds with color G quality
# - Diamonds with SI1 clarity rating
# - Diamonds with ideal cuts
#
# Additionally, we find the following trends:
#
# - Cummulative aggregated prices for color and clarity doesn't necessarily indicate that the best rated attributes are the most desirable ones.
# - In a similar manner, we find that the frequency for the best rated color and clarity are not the highest ones. We find that low clarity is common as well as a preference for mid rated colors.
# - When we look at cut,there is an evident order that indicates that the best cuts tend to represent more money. Accross all three categories, the only one that evidences a logical order of frequency and value is the cut type.
#
# We consider that there is a clear preference for best cuts, therefore, it opens a an opportunity for further analysis and makes us formulate this question:
#
# **Is the cut the most important attribute?**

# %% [markdown]
# According to experts, the Cut of a diamond is perhaps the most important aspect of a diamond quality that impacts a diamond’s beauty. Diamond Cut specifically refers to the quality of a diamond’s angles, proportions, symmetrical facets, brilliance, fire, scintillation and finishing details. These factors directly impact a diamond’s ability to sparkle, along with its overall aesthetic appeal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5) Inferential Statistics

# %% [markdown]
# To continue exploring the data, we perform inferential statistics to in order to find additional key findings from our dataset.

# %% [markdown]
# **5.1 Correlation Among Quantitative Variables**

# %% [markdown]
# First, considering all numerical variables, we display a correlation matrix. It will tell us the direction and strength of the relationships between them. This step is performed for the entire dataset.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The results suggest three things:
#
# 1. The variables carat, length, width, and depth present a strong uphill (positive) linear relationship to the price of a diamond.
# 2. The variable total_percent_depth presents mainly a weak downhill (negative) linear relationship to price of a diamond.
# 3. The variable table presents mainly a weak uphill (positive) linear relationship to the price of a diamond.

# %% [markdown]
# **5.2 Multiple Regression**

# %% [markdown]
# As regression is one of the most popular techniques in statistics, we want to use it to determine the level of change that price experiences, given the other quantitative variables in the dataset.
#
# The variables are defined as follows:
#
# Y = df[['price']] as the dependent variable
#
# X = df[['total_percent_depth','length', 'table','width','depth']] independent variables
#
# Note: Carat is not included as a variable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $ \mathrm{Base\; on\; model:\;Y = \beta_{1}x_{1} + \beta_{2}x_{2} + ...+ \beta_{n}x_{n} + \beta_{0}} \\
# \mathrm{\therefore Price = -115.1554\times total\;percent\;depth -125.4539\times table + 2751.3544\times length + 154.8904\times width + 451.3716\times depth}$

# %% [markdown]
# **5.2.1 Descriptive Statistics by Cut Type**

# %% [markdown]
# Based on the EDA performed, we find that cut might have relevance. Therefore, we decided to further explore the differences among these categories by performing descriptive statistics.

# %% [markdown]
# ![Screenshot%20%2868%29.png](attachment:Screenshot%20%2868%29.png)|![Screenshot%20%2869%29.png](attachment:Screenshot%20%2869%29.png) | ![Screenshot%20%2870%29.png](attachment:Screenshot%20%2870%29.png) |![Screenshot%20%2871%29.png](attachment:Screenshot%20%2871%29.png)|![Screenshot%20%2872%29.png](attachment:Screenshot%20%2872%29.png)| ![Screenshot%20%2873%29.png](attachment:Screenshot%20%2873%29.png)|![Screenshot%20%2874%29.png](attachment:Screenshot%20%2874%29.png)

# %% [markdown]
# Breaking down, the descriptive statistics by cut type, the mean price for the fair type is \\$4358.758 with a mean carat weight of around 1.0461. And Good and Very Good cuts have mean price of \\$3928.864, and \\$3981.76 with mean carat weight of around 0.8492, and 0.806 respectively. The Ideal and Premium cut types have mean prices of \\$3457.542 and \\$4584.258 and average carat weight of 0.703, and 0.892 respectivley.

# %% [markdown]
# **5.2.2 Multiple Regression with Dummy Variable by Cut Type**

# %% [markdown]
# Despite knowing the effect that each variable has in price, we want to determine the effect each avriable has on price by separating them in groups. For this, we are performing a regression with a dummy variable for each cut type. This regression runs based on the presence or absence of determined categorical variables.
#
# Results are as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Considering our conclusion on cut importance, we group by cut and perform regressions where we find:
# - Effects of the variable vary accross samples:
#        -For premium cut: The length and depth seem to be the most influential factors in price change. These represents positive relationships on price.
#        - For ideal cut: Three factors have a positive influence on price, those are length, width, and depth.
#        - For very good cut: Three factors have a positive influence on price, those are length, width, and depth.
#        - For good cut: Only width and depth have a positive influence on price.
#        - For fair cut: Three factors have a positive influence on price, those are length, width, and depth.
#
# Depth represents the only variable that is able to positively influence price across samples. All samples have either 2 or 3 variables that have a positive relationship with price, however, the level of impact is different, this means, the level of relevance for each x varies for each cut type of diamonds.

# %% [markdown]
# **5.3 ANOVA**

# %% [markdown]
# For the ANOVA analysis we focused on checking the relationship between the 5 cut type groups and their prices. Before proceeding with the analysis, we implemented the 3 assumption checks:
#
# 1) Independence:
#
# * Tested during the design of the study. All groups must be mutually exclusive, i.e. in our data, a diamond can only belong in one of the cut type group.
#
# 2) Normality:
#
# * We checked for normality using the **Shapiro-walk** test from scipy.stats.
#
# 3) Homogeniety of Variance
#
# * we checked for equal variance among groups using the **Barlette's and Levene's** test

# %% [markdown]
# **5.3.1 Shapiro-Walk Normality test**

# %% [markdown]
# Ho : data is normally distributed
# Ha: data is not normally distributed
#
# Out put was a **p-value: 0.917**. We accepted the null hypothesis that our data was normally distributed.

# %% [markdown]
# **5.3.2 Homogeneity of Variance - Barlett's Test**

# %% [markdown]
# Ho : Our 5 groups categorized by cut type have equal variance
# Ha: Our 5 groups categorized by cut type don not have equal variance
#
# our p-value was less than 0.05, which indicated that we reject our null hypothesis that our groups have equal variances. Since the Barlett's test was a bit sensitive to variance differnces, we also checked using Leven's test. However, both test confirmed that our groups do not have equal variances. This was mainly due to the number of samples in each of our 5 groups were hugely different, resulting a biased variances. Hence, parametric test such as ANOVA, t-test can not be perfomred in our samples. As a result, we chose to perform **Kruskal-Wallis** test for the non-parametric analysis.

# %% [markdown]
# **5.3.3 Kruskal-Wallis Non-Parametric Test**

# %% [markdown]
# Ho: The mean price of the 5 cut groups are the same
# Ha: The mean prices of the 5 cut groups are different
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Kruskal-Wallis analysis, shows that the mean prices for the different cut groups are different.

# %% [markdown]
# # 7) Conclusion and Result Reliability
#
# Our analysis let us conclude the following:
#
# - From the EDA performed, the categorical variable that has more influence is the cut type.
#
# - Carat has a direct relationship with price.
#
# - carat, price, length, width, and depth present a strong uphill (positive) linear relationship, correlation exist.
#
# - For the entire dataset length, width, and depth will affect the price of the diamond. However, this result doesn't hold when we look at cut types independently. The only variable that positively influences the prices is the depth according to our results.
#
# - ANOVA and other parametric tests are not a suitable test for this data because the samples sizes in each of the 5 cut groups were hugely different, which resulted in a biased and uneqaul variance.
#
# - From the non-parametric Kruskal_Wallis test, we concluded the different samples grouped by cut type have different mean prices.
#
# Results reliability is conditioned because:
#
# - We experience "selection bias" which means that since we don't know the source of the data, it could lead us to believe that it is made up data.
#
# - No timeframe of the data. As data over time changes, we could assume this is old data which can lead into innacurate data points.
#
# - Model specification: We are skeptical to conclude that this model is well specified due to data limitations. We believe that there might be additional variables that can help us to build more accurate models and hence more powerful specifications.
#
# To finalize:
#
# - Model execution: We consider it accurate as we followed in detail all the statistical processes.
#
# - Our overall analysis sets clear differnces between the parametric and non-parametric statistical analysis.
#
# - We are confident that our EDA is strong and concise as we cover all aspects that includes data analysis techniques and the usage of effective visualization tools.
